# %%
library(ggplot2)
library(dplyr)
library(tidyr)

library(foreign)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# gss = read.dta("/Users/annacoenen/GoogleDrive/NYU_GD/MLClass/Societal\ Attitudes\ and\ Court\ Cases/data/GSS7212_R2.DTA")
gss = read.dta("/Users/gureckislab/GoogleDrive/NYU_GD/MLClass/Societal\ Attitudes\ and\ Court\ Cases/data/GSS7212_R2.DTA")
# Out:
# Warning message:
# In `levels<-`(`*tmp*`, value = if (nl == nL) as.character(labels) else paste0(labels, : duplicated levels in factors are deprecatedWarning message:
# In `levels<-`(`*tmp*`, value = if (nl == nL) as.character(labels) else paste0(labels, : duplicated levels in factors are deprecatedWarning message:
# In `levels<-`(`*tmp*`, value = if (nl == nL) as.character(labels) else paste0(labels, : duplicated levels in factors are deprecatedWarning message:
# In `levels<-`(`*tmp*`, value = if (nl == nL) as.character(labels) else paste0(labels, : duplicated levels in factors are deprecatedWarning message:
# In `levels<-`(`*tmp*`, value = if (nl == nL) as.character(labels) else paste0(labels, : duplicated levels in factors are deprecatedWarning message:
# In `levels<-`(`*tmp*`, value = if (nl == nL) as.character(labels) else paste0(labels, : duplicated levels in factors are deprecatedWarning message:
# ...

# %%
gss %>% head(10)
# Out:
#    year id          wrkstat hrs1 hrs2 evwork occ prestige       wrkslf wrkgovt
# 1  1972  1 working fulltime   NA   NA   <NA> 205       50 someone else    <NA>
# 2  1972  2          retired   NA   NA    yes 441       45 someone else    <NA>
# 3  1972  3 working parttime   NA   NA   <NA> 270       44 someone else    <NA>
# 4  1972  4 working fulltime   NA   NA   <NA>   1       57 someone else    <NA>
# 5  1972  5    keeping house   NA   NA    yes 385       40 someone else    <NA>
# 6  1972  6 working fulltime   NA   NA   <NA> 281       49 someone else    <NA>
# 7  1972  7 working fulltime   NA   NA   <NA> 522       41 someone else    <NA>
# 8  1972  8 working fulltime   NA   NA   <NA> 314       36 someone else    <NA>
# 9  1972  9 working parttime   NA   NA   <NA> 912       26 someone else    <NA>
# 10 1972 10 working fulltime   NA   NA   <NA> 984       18 someone else    <NA>
#    commute industry occ80 prestg80 indus80 occ10 indus10       marital agewed
# ...

# %%
# raceData = gss %>%    
#         select(year,age,id,sex,race,racavoid,racmar,racdin,racpush,racseg,racschol,racfew,rachaf,closeblk,feelblks,racjob,racmarel,racmarpr,racobjct,racopen,racpush,racquit,racsubs,racsups,racteach,wrkwayup)
raceData = gss %>%  
        filter(as.numeric(year)>1974, age>17,race=='white') %>% 
        select(year,age,id,sex,race,racmar,racpres,racseg,racfew,rachaf,racmost)

raceData %>% head(100)
# Out:
# Warning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# ...

# %%
# raceData %>% 
#     group_by(year) %>%
#     summarize_each(first(unique(.)))
    
# Not sure if dk should really be NA, but leaving this for now
raceData[raceData[,]=="iap"] <- NA
raceData[raceData[,]=="dk"] <- NA
sapply(droplevels(raceData),levels)
# Out:
# Error in vapply(seq_along(mapped), function(i) {: values must be length 1,
#  but FUN(X[[1]]) result is length 0
# $year
# NULL
#
# $age
# NULL
#
# $id
# NULL
#
# $sex
# [1] "male"   "female"
#
# $race
# [1] "white"
#
# $racmar
# [1] "yes" "no"
#
# $racpres
# [1] "yes" "no"
#
# $racseg
# [1] "agree strongly"    "agree slightly"    "disagree slightly"
# [4] "disagree strongly"
#
# $racfew
# [1] "yes, object" "no"
#
# $rachaf
# [1] "yes, object" "no"
#
# $racmost
# [1] "yes, object" "no"

# %%
raceDataCoded = raceData %>%
    mutate(racmarC= racmar =="yes",
          racpresC = racpres == "no",
          racsegC = rev(as.numeric(racseg)))
raceDataCoded$racPeers = NA
raceDataCoded[,raceDataCoded$racmost == "no"]$racPeers = 0
# raceDataCoded$racPeers = (raceDataCoded$racfew == "yes, object")+1
# raceDataCoded$racPeers = (raceDataCoded$rachaf == "yes, object")+2
# raceDataCoded$racPeers = (raceDataCoded$racmost == "yes, object")+3


raceDataCoded %>% head(100)
# Out:
# Error in `[.data.frame`(`*tmp*`, , raceDataCoded$racmost == "no"): undefined columns selected
# Warning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# ...

# %%
raceData %>% 
    filter(as.numeric(year)>1974, age>17,race=='white') %>% 
    group_by(year) %>% 
    summarise_each(funs(mean(.,na.rm=TRUE)))
# Out:
# Warning message:
# In mean.default(structure(c(1L, 2L, 2L, 1L, 1L, 2L, 2L, 2L, 1L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 1L, 1L, 2L, 1L, 1L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 1L, 2L, 1L, 2L, 2L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(1L, 1L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(1L, 2L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 1L, 2L, 1L, 2L, 2L, 2L, : argument is not numeric or logical: returning NAWarning message:
# ...

# %% [markdown]
# ## sdfdf

# %%
raceData %>% 
    filter(as.numeric(year)>1974) %>% 
    group_by(year) %>% 
    summarise_each(funs(mean(.,na.rm=TRUE)))%>% 
    head(10)
# Out:
# Warning message:
# In mean.default(structure(c(1L, 2L, 2L, 1L, 1L, 2L, 2L, 2L, 1L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 1L, 1L, 2L, 1L, 1L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 1L, 2L, 1L, 2L, 2L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(1L, 1L, 2L, 2L, 2L, 1L, 1L, 2L, 1L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(1L, 2L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, : argument is not numeric or logical: returning NAWarning message:
# In mean.default(structure(c(2L, 2L, 1L, 1L, 2L, 1L, 2L, 2L, 2L, : argument is not numeric or logical: returning NAWarning message:
# ...

# %%
# Out:
# Warning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋱"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# ...
